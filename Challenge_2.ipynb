# %%
import matplotlib.pyplot as plt
from tabulate import tabulate
import matplotlib as mat
import seaborn as sns
import pandas as pd    
import numpy as np

pd.set_option('display.max_columns', None)

# %%
df=pd.read_excel('DS1_C5_S2_Income_Data_Challenge.xlsx')

# %% [markdown]
# # Task1:

# %%
def separate(df):
    categorical = []
    continuous = []
    for column in df.columns:
        if df[column].nunique()<50:
            categorical.append(column)
        else:
             continuous.append(column)
                
    return categorical, continuous 
categorical, continuous = separate(df)
from tabulate import tabulate
table = [categorical, continuous]
print(tabulate({"Categorical":categorical,
                "continuous": continuous}, headers = ["categorical", "continuous"]))
# Out:
# categorical     continuous
# --------------  --------------
# WorkClass       Age
# Education       Hours_Per_Week
# Education_Num
# Marital_Status
# Occupation
# Relationship
# Gender
# Native_Country
# Income_Bracket

# %% [markdown]
# # Task2:

# %%
fig, ax = plt.subplots(figsize = (12, 5))
sns.countplot(x = "WorkClass", hue = "Income_Bracket", data = df)
plt.show()

# %% [markdown]
# ### Most individuals whose salary is <= 50K are working in private sector

# %%
fig, ax = plt.subplots(figsize = (18, 6))
sns.countplot(x = "Education", hue = "Income_Bracket", data = df)
plt.show()

# %% [markdown]
# ### most working individuals have either done bachelors or HS-grade or Some-college

# %%
fig, ax = plt.subplots(figsize = (10, 5))
sns.countplot(x = "Education_Num", hue = "Income_Bracket", data = df)
plt.show()

# %% [markdown]
# ### most working individuals of both income category have either 9,10 or 13 education_num

# %%
fig, ax = plt.subplots(figsize = (16, 7))
sns.countplot(x = "Marital_Status", hue = "Income_Bracket", data = df)
plt.show()

# %% [markdown]
# ### Most Individuals whose salary <=50k are never married or married-civ-spouse or divorced. AND 85% Individuals with salary>50k are Married-civ-spouse

# %%
fig, ax = plt.subplots(figsize = (25, 7))
sns.countplot(x = "Occupation", hue = "Income_Bracket", data = df)
plt.show()

# %% [markdown]
# ### Exec-managerical and prof-speciality are high paying jobs

# %%
fig, ax = plt.subplots(figsize = (10, 4))
sns.countplot(x = "Relationship", hue = "Income_Bracket", data = df)
plt.show()

# %% [markdown]
# ### Most individuals with salary>50k are husband

# %%
fig, ax = plt.subplots(figsize = (10, 4))
sns.countplot(x = "Gender", hue = "Income_Bracket", data = df)
plt.show()

# %% [markdown]
# ### Most individuals with salary>50k are male

# %%
fig, ax = plt.subplots(figsize = (20, 7))
sns.countplot(x = "Native_Country", hue = "Income_Bracket", data = df)
plt.show()

# %% [markdown]
# ### Most individuals of both category belong to united states

# %%
fig, ax = plt.subplots(figsize = (10, 4))
sns.countplot(x = "Income_Bracket", hue = "Income_Bracket", data = df)
plt.show()

# %% [markdown]
# ### around 25000 have salary<=50k and around 7500 have salary>50k

# %% [markdown]
# # Task3:

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
sns.histplot(x = df["Age"], hue = df["Income_Bracket"], ax = ax[0])
sns.boxplot(y = df["Age"], x = df["Income_Bracket"], ax = ax[1])
plt.show()

# %% [markdown]
# ### most individuals who are getting higher salary are from 35-50 years of age group

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
sns.histplot(x = df["Education_Num"], hue = df["Income_Bracket"], ax = ax[0])
sns.boxplot(y = df["Education_Num"], x = df["Income_Bracket"], ax = ax[1])
plt.show()

# %% [markdown]
# ### most individuals who are getting higher salary have 10-13 education_num

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
sns.histplot(x = df["Hours_Per_Week"], hue = df["Income_Bracket"], ax = ax[0])
sns.boxplot(y = df["Hours_Per_Week"], x = df["Income_Bracket"], ax = ax[1])
plt.show()

# %% [markdown]
# ### Individuals getting higher salary are working more hours_per_week than individuals getting less salary
