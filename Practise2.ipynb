# %%
import matplotlib.pyplot as plt
from tabulate import tabulate
import matplotlib as mat
import seaborn as sns
import pandas as pd    
import numpy as np

pd.set_option('display.max_columns', None)

# %%
df=pd.read_csv('DS1_C5_S2_EmployeeAttrition_Data_Practice.csv')

# %%
def separate(df):
    categorical = []
    continuous = []
    for column in df.columns:
        if df[column].nunique()<50:
            categorical.append(column)
        else:
             continuous.append(column)
                
    return categorical, continuous 
categorical, continuous = separate(df)
from tabulate import tabulate
table = [categorical, continuous]
print(tabulate({"Categorical":categorical,
                "continuous": continuous}, headers = ["categorical", "continuous"]))
# Out:
# categorical               continuous
# ------------------------  --------------
# Age                       EmployeeNumber
# Attrition                 HourlyRate
# BusinessTravel            MonthlyIncome
# Department
# DistanceFromHome
# EducationField
# EnvironmentSatisfaction
# Gender
# JobInvolvement
# JobRole
# JobSatisfaction
# MaritalStatus
# NumCompaniesWorked
# Over18
# OverTime
# PerformanceRating
# RelationshipSatisfaction
# TotalWorkingYears
# TrainingTimesLastYear
# WorkLifeBalance
# YearsAtCompany
# YearsInCurrentRole
# YearsSinceLastPromotion
# YearsWithCurrManager

# %% [markdown]
# # Task1:

# %%
fig, ax = plt.subplots(figsize = (10, 7))
sns.countplot(x = "BusinessTravel", hue = "Attrition", data = df)
plt.show()

# %% [markdown]
# ### we can see that most of employees travel rarely

# %%
fig, ax = plt.subplots(figsize = (10, 7))
sns.countplot(x = "EducationField", hue = "Attrition", data = df)
plt.show()

# %% [markdown]
# ### we can see that most of employees are from life scriences and medical educational background

# %%
fig, ax = plt.subplots(figsize = (10, 7))
sns.countplot(x = "Department", hue = "Attrition", data = df)
plt.show()

# %% [markdown]
# ### we can see that most of employees are from R&D Department

# %%
fig, ax = plt.subplots(figsize = (10, 7))
sns.countplot(x = "EnvironmentSatisfaction", hue = "Attrition", data = df)
plt.show()

# %% [markdown]
# ### we can see that most of employees have 3&4 environment satisfaction.

# %%
fig, ax = plt.subplots(figsize = (10, 7))
sns.countplot(x = "Gender", hue = "Attrition", data = df)
plt.show()

# %% [markdown]
# ### There is majority of males in the company

# %%
fig, ax = plt.subplots(figsize = (10, 7))
sns.countplot(x = "MaritalStatus", hue = "Attrition", data = df)
plt.show()

# %% [markdown]
# ### most of employees are married

# %%
fig, ax = plt.subplots(figsize = (10, 7))
sns.countplot(x = "OverTime", hue = "Attrition", data = df)
plt.show()

# %% [markdown]
# ### Majority of employees dont do overtime.

# %%
fig, ax = plt.subplots(figsize = (10, 7))
sns.countplot(x = "PerformanceRating", hue = "Attrition", data = df)
plt.show()

# %% [markdown]
# ### Most employees have 3 performace rating

# %%
fig, ax = plt.subplots(figsize = (10, 7))
sns.countplot(x = "JobSatisfaction", hue = "Attrition", data = df)
plt.show()

# %% [markdown]
# ### we can see that most of employees have 3&4 level of satisfaction

# %% [markdown]
# # Task2:

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
sns.histplot(x = df["Age"], hue = df["Attrition"], ax = ax[0])
sns.boxplot(y = df["Age"], x = df["Attrition"], ax = ax[1])
plt.show()

# %% [markdown]
# ### most employees who left the company are from 28-40 years age group.and most of employees who are still working are from 30-43 years age group

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
sns.histplot(x = df["HourlyRate"], hue = df["Attrition"], ax = ax[0])
sns.boxplot(y = df["HourlyRate"], x = df["Attrition"], ax = ax[1])
plt.show()

# %% [markdown]
# ### both attrited and non-attrited employees have same hourly rates.

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
sns.histplot(x = df["MonthlyIncome"], hue = df["Attrition"], ax = ax[0])
sns.boxplot(y = df["MonthlyIncome"], x = df["Attrition"], ax = ax[1])
plt.show()

# %% [markdown]
# ### employees who left the company mostly belong to who were getting less monthly income(around2500-6000).

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
sns.histplot(x = df["DistanceFromHome"], hue = df["Attrition"], ax = ax[0])
sns.boxplot(y = df["DistanceFromHome"], x = df["Attrition"], ax = ax[1])
plt.show()

# %% [markdown]
# ### most employees who left the company were living far from office(around 5-17 miles)

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
sns.histplot(x = df["TotalWorkingYears"], hue = df["Attrition"], ax = ax[0])
sns.boxplot(y = df["TotalWorkingYears"], x = df["Attrition"], ax = ax[1])
plt.show()

# %% [markdown]
# ### most employees with 3-10 years of experience left the company

# %% [markdown]
# # Task3:

# %%
T3=df[(df['Attrition']=='Yes')&(df['BusinessTravel']=='Travel_Rarely')]

# %%
T3_=T3.groupby(by='JobRole')['Attrition'].count()

# %%
plt.barh(y=T3_.index,width=T3_.values)
# Out:
# <BarContainer object of 9 artists>

# %% [markdown]
# ### We can see that the employees who left the company and were travelling rarely, they mostly belong to sales and laboratory tech. job role

# %% [markdown]
# ## Task4:

# %%
T4=df[(df['EducationField']=='Life Sciences')|(df['EducationField']=='Medical')]

# %%
T4_=T4.groupby(by='JobRole')['Attrition'].count()

# %%
fig, ax = plt.subplots(figsize = (10, 7))
sns.countplot(y = "JobRole", hue = "Attrition", data = T4)
plt.show()

# %% [markdown]
# ### most of employees are working as sales executives,research scientists,laboratory technician

# %% [markdown]
# ## Task5:

# %%
T5=df[(df['Department']=='Sales')]

# %%
fig, ax = plt.subplots(figsize = (10, 7))
sns.countplot(x = "Gender", hue = "Attrition", data = T4)
plt.show()

# %% [markdown]
# ### sales department have majority of males
