# %%
import matplotlib.pyplot as plt
from tabulate import tabulate
import matplotlib as mat
import seaborn as sns
import pandas as pd    
import numpy as np

pd.set_option('display.max_columns', None)

# %%
df=pd.read_csv('DS1_C5_S4_Credit_Data_Hackathon.csv')

# %% [markdown]
# # Level 0 Analysis

# %%
df.head()
# Out:
#    SK_ID_CURR  TARGET NAME_CONTRACT_TYPE GENDER Car House  CNT_CHILDREN  \
# 0      100002       1         Cash loans      M   N     Y             0
# 1      100003       0         Cash loans      F   N     N             0
# 2      100004       0    Revolving loans      M   Y     Y             0
# 3      100006       0         Cash loans      F   N     Y             0
# 4      100007       0         Cash loans      M   N     Y             0
#
#    AMT_INCOME_TOTAL  AMT_CREDIT  AMT_GOODS_PRICE NAME_TYPE_SUITE  \
# 0          202500.0    406597.5         351000.0   Unaccompanied
# 1          270000.0   1293502.5        1129500.0          Family
# 2           67500.0    135000.0         135000.0   Unaccompanied
# 3          135000.0    312682.5         297000.0   Unaccompanied
# 4          121500.0    513000.0         513000.0   Unaccompanied
#
#   NAME_INCOME_TYPE            NAME_EDUCATION_TYPE    NAME_FAMILY_STATUS  \
# ...

# %%
df.tail()
# Out:
#        SK_ID_CURR  TARGET NAME_CONTRACT_TYPE GENDER Car House  CNT_CHILDREN  \
# 99995      216086       0         Cash loans      F   N     Y             1
# 99996      216087       0         Cash loans      F   N     Y             1
# 99997      216088       0         Cash loans      F   Y     Y             0
# 99998      216089       0         Cash loans      F   Y     N             0
# 99999      216090       0    Revolving loans      M   Y     Y             0
#
#        AMT_INCOME_TOTAL  AMT_CREDIT  AMT_GOODS_PRICE NAME_TYPE_SUITE  \
# 99995          157500.0    755190.0         675000.0   Unaccompanied
# 99996          225000.0    284400.0         225000.0   Unaccompanied
# 99997          135000.0   1262583.0        1102500.0          Family
# 99998          135000.0    225000.0         225000.0   Unaccompanied
# 99999          202500.0    337500.0         337500.0   Unaccompanied
#
#            NAME_INCOME_TYPE            NAME_EDUCATION_TYPE NAME_FAMILY_STATUS  \
# ...

# %%
df.shape
# Out:
# (100000, 24)

# %%
df.columns
# Out:
# Index(['SK_ID_CURR', 'TARGET', 'NAME_CONTRACT_TYPE', 'GENDER', 'Car', 'House',
#        'CNT_CHILDREN', 'AMT_INCOME_TOTAL', 'AMT_CREDIT', 'AMT_GOODS_PRICE',
#        'NAME_TYPE_SUITE', 'NAME_INCOME_TYPE', 'NAME_EDUCATION_TYPE',
#        'NAME_FAMILY_STATUS', 'DAYS_EMPLOYED', 'MOBILE', 'WORK_PHONE',
#        'HOME_PHONE', 'MOBILE_REACHABLE', 'FLAG_EMAIL', 'OCCUPATION_TYPE',
#        'CNT_FAM_MEMBERS', 'APPLICATION_DAY', 'TOTAL_DOC_SUBMITTED'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 24 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   SK_ID_CURR           100000 non-null  int64
#  1   TARGET               100000 non-null  int64
#  2   NAME_CONTRACT_TYPE   100000 non-null  object
#  3   GENDER               100000 non-null  object
#  4   Car                  100000 non-null  object
#  5   House                100000 non-null  object
#  6   CNT_CHILDREN         100000 non-null  int64
#  7   AMT_INCOME_TOTAL     100000 non-null  float64
#  8   AMT_CREDIT           100000 non-null  float64
#  9   AMT_GOODS_PRICE      99919 non-null   float64
#  10  NAME_TYPE_SUITE      99595 non-null   object
#  11  NAME_INCOME_TYPE     100000 non-null  object
#  12  NAME_EDUCATION_TYPE  100000 non-null  object
#  13  NAME_FAMILY_STATUS   100000 non-null  object
#  14  DAYS_EMPLOYED        100000 non-null  int64
# ...

# %%
df.isnull().sum()
# Out:
# SK_ID_CURR                 0
# TARGET                     0
# NAME_CONTRACT_TYPE         0
# GENDER                     0
# Car                        0
# House                      0
# CNT_CHILDREN               0
# AMT_INCOME_TOTAL           0
# AMT_CREDIT                 0
# AMT_GOODS_PRICE           81
# NAME_TYPE_SUITE          405
# NAME_INCOME_TYPE           0
# NAME_EDUCATION_TYPE        0
# NAME_FAMILY_STATUS         0
# DAYS_EMPLOYED              0
# MOBILE                     0
# WORK_PHONE                 0
# HOME_PHONE                 0
# MOBILE_REACHABLE           0
# FLAG_EMAIL                 0
# OCCUPATION_TYPE        31224
# CNT_FAM_MEMBERS            1
# APPLICATION_DAY            0
# TOTAL_DOC_SUBMITTED        0
# dtype: int64

# %% [markdown]
# # Level 1 Analysis:

# %%
def separate(df):
    categorical = []
    continuous = []
    for column in df.columns:
        if df[column].nunique()<100:
            categorical.append(column)
        else:
             continuous.append(column)
                
    return categorical, continuous 
categorical, continuous = separate(df)

table = [categorical, continuous]
print(tabulate({"Categorical":categorical,
                "continuous": continuous}, headers = ["categorical", "continuous"]))
# Out:
# categorical          continuous
# -------------------  ----------------
# TARGET               SK_ID_CURR
# NAME_CONTRACT_TYPE   AMT_INCOME_TOTAL
# GENDER               AMT_CREDIT
# Car                  AMT_GOODS_PRICE
# House                DAYS_EMPLOYED
# CNT_CHILDREN
# NAME_TYPE_SUITE
# NAME_INCOME_TYPE
# NAME_EDUCATION_TYPE
# NAME_FAMILY_STATUS
# MOBILE
# WORK_PHONE
# HOME_PHONE
# MOBILE_REACHABLE
# FLAG_EMAIL
# OCCUPATION_TYPE
# CNT_FAM_MEMBERS
# APPLICATION_DAY
# TOTAL_DOC_SUBMITTED

# %%
def info_of_cat(col): 
    print(f"Unique values in {col} are: {df[col].unique()}") 
    print(f"Mode of {col} is {df[col].mode()[0]}")
    print(f"Number of missing values in {col} is {df[col].isnull().sum()}")

# %%
info_of_cat('TARGET')
# Out:
# Unique values in TARGET are: [1 0]
# Mode of TARGET is 0
# Number of missing values in TARGET is 0

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
ax[0].set_title("TARGET")                  
percentage = df["TARGET"].value_counts()        
labels = list(df["TARGET"].value_counts().index)

sns.countplot(x = df["TARGET"], ax = ax[0])
plt.pie(percentage,labels = labels, autopct= "%0.2f%%")  

plt.show()

# %% [markdown]
# ### Interpretation: around 8%(8000+ in count) of clients are unable to repay the loan in time.

# %%
info_of_cat('NAME_CONTRACT_TYPE')
# Out:
# Unique values in NAME_CONTRACT_TYPE are: ['Cash loans' 'Revolving loans']
# Mode of NAME_CONTRACT_TYPE is Cash loans
# Number of missing values in NAME_CONTRACT_TYPE is 0

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
ax[0].set_title("NAME_CONTRACT_TYPE")                  
percentage = df["NAME_CONTRACT_TYPE"].value_counts()        
labels = list(df["NAME_CONTRACT_TYPE"].value_counts().index)

sns.countplot(x = df["NAME_CONTRACT_TYPE"], ax = ax[0])
plt.pie(percentage,labels = labels, autopct= "%0.2f%%")  

plt.show()

# %% [markdown]
# ## 90.52% are cash loans and rest are revolving loans

# %%
info_of_cat('GENDER')
# Out:
# Unique values in GENDER are: ['M' 'F' 'XNA']
# Mode of GENDER is F
# Number of missing values in GENDER is 0

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
ax[0].set_title("GENDER")                  
percentage = df["GENDER"].value_counts()        
labels = list(df["GENDER"].value_counts().index)

sns.countplot(x = df["GENDER"], ax = ax[0])
plt.pie(percentage,labels = labels, autopct= "%0.2f%%")  

plt.show()

# %% [markdown]
# ### around 65.86% of loan clients are female and rest are male.

# %%
info_of_cat('Car')
# Out:
# Unique values in Car are: ['N' 'Y']
# Mode of Car is N
# Number of missing values in Car is 0

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
ax[0].set_title("Car")                  
percentage = df["Car"].value_counts()        
labels = list(df["Car"].value_counts().index)

sns.countplot(x = df["Car"], ax = ax[0])
plt.pie(percentage,labels = labels, autopct= "%0.2f%%")  

plt.show()

# %% [markdown]
# ### around 66% of loan takers client do not own the car and rest own the car

# %%
info_of_cat('House')
# Out:
# Unique values in House are: ['Y' 'N']
# Mode of House is Y
# Number of missing values in House is 0

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
ax[0].set_title("House")                  
percentage = df["House"].value_counts()        
labels = list(df["House"].value_counts().index)

sns.countplot(x = df["House"], ax = ax[0])
plt.pie(percentage,labels = labels, autopct= "%0.2f%%")  

plt.show()

# %% [markdown]
# ### 69.22% cilents own a house and 30.67% dont.

# %%
info_of_cat('CNT_CHILDREN')
# Out:
# Unique values in CNT_CHILDREN are: [ 0  1  2  3  4  7  5  6  8  9 11 12]
# Mode of CNT_CHILDREN is 0
# Number of missing values in CNT_CHILDREN is 0

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
ax[0].set_title("CNT_CHILDREN")                  
percentage = df["CNT_CHILDREN"].value_counts()        
labels = list(df["CNT_CHILDREN"].value_counts().index)

sns.countplot(x = df["CNT_CHILDREN"], ax = ax[0])
plt.pie(percentage,labels = labels, autopct= "%0.2f%%")  

plt.show()

# %% [markdown]
# ### almost 70% client don't have any childerns and 20% have 1 and 8.59% have 2 childrens

# %%
info_of_cat('NAME_TYPE_SUITE')
# Out:
# Unique values in NAME_TYPE_SUITE are: ['Unaccompanied' 'Family' 'Spouse, partner' 'Children' 'Other_A' nan
#  'Other_B' 'Group of people']
# Mode of NAME_TYPE_SUITE is Unaccompanied
# Number of missing values in NAME_TYPE_SUITE is 405

# %%
NAME_TYPE_SUITE_mode=df.NAME_TYPE_SUITE.mode()[0]
print(NAME_TYPE_SUITE_mode)
df['NAME_TYPE_SUITE'].fillna(NAME_TYPE_SUITE_mode,inplace=True)
# Out:
# Unaccompanied

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
ax[0].set_title("NAME_TYPE_SUITE")                  
percentage = df["NAME_TYPE_SUITE"].value_counts()        
labels = list(df["NAME_TYPE_SUITE"].value_counts().index)

sns.countplot(x = df["NAME_TYPE_SUITE"], ax = ax[0])
plt.pie(percentage,labels = labels, autopct= "%0.2f%%")  

plt.show()

# %% [markdown]
# ## 81.19% clients were unaccompanied and 13.10 was family

# %%
info_of_cat('NAME_INCOME_TYPE')
# Out:
# Unique values in NAME_INCOME_TYPE are: ['Working' 'State servant' 'Commercial associate' 'Pensioner' 'Unemployed'
#  'Student' 'Businessman' 'Maternity leave']
# Mode of NAME_INCOME_TYPE is Working
# Number of missing values in NAME_INCOME_TYPE is 0

# %%
fig, ax = plt.subplots(1, 2, figsize = (22,7))
ax[0].set_title("NAME_INCOME_TYPE")                  
percentage = df["NAME_INCOME_TYPE"].value_counts()        
labels = list(df["NAME_INCOME_TYPE"].value_counts().index)

sns.countplot(x = df["NAME_INCOME_TYPE"], ax = ax[0])
plt.pie(percentage,labels = labels, autopct= "%0.2f%%")  

plt.show()

# %% [markdown]
# ### almost 52% clients were working & 23.22% were commercial associate and 17.86% were pensioner and 7% were state servant

# %%
info_of_cat('NAME_EDUCATION_TYPE')
# Out:
# Unique values in NAME_EDUCATION_TYPE are: ['Secondary / secondary special' 'Higher education' 'Incomplete higher'
#  'Lower secondary' 'Academic degree']
# Mode of NAME_EDUCATION_TYPE is Secondary / secondary special
# Number of missing values in NAME_EDUCATION_TYPE is 0

# %%
fig, ax = plt.subplots(1, 2, figsize = (22,7))
ax[0].set_title("NAME_EDUCATION_TYPE")                  
percentage = df["NAME_EDUCATION_TYPE"].value_counts()        
labels = list(df["NAME_EDUCATION_TYPE"].value_counts().index)

sns.countplot(x = df["NAME_EDUCATION_TYPE"], ax = ax[0])
plt.pie(percentage,labels = labels, autopct= "%0.2f%%")  

plt.show()

# %% [markdown]
# ### 71% were secondary education qualified when applying for loan and 24.40% were with higher education.

# %%
info_of_cat('NAME_FAMILY_STATUS')
# Out:
# Unique values in NAME_FAMILY_STATUS are: ['Single / not married' 'Married' 'Civil marriage' 'Widow' 'Separated'
#  'Unknown']
# Mode of NAME_FAMILY_STATUS is Married
# Number of missing values in NAME_FAMILY_STATUS is 0

# %%
fig, ax = plt.subplots(1, 2, figsize = (17, 7))
ax[0].set_title("NAME_FAMILY_STATUS")                  
percentage = df["NAME_FAMILY_STATUS"].value_counts()        
labels = list(df["NAME_FAMILY_STATUS"].value_counts().index)

sns.countplot(x = df["NAME_FAMILY_STATUS"], ax = ax[0])
plt.pie(percentage,labels = labels, autopct= "%0.2f%%")  

plt.show()

# %% [markdown]
# ### almost 64% were married clients and 14.57% were unmarried and 9.77% falls in category of civil marriage

# %%
info_of_cat('MOBILE')
# Out:
# Unique values in MOBILE are: [1 0]
# Mode of MOBILE is 1
# Number of missing values in MOBILE is 0

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
ax[0].set_title("MOBILE")                  
percentage = df["MOBILE"].value_counts()        
labels = list(df["MOBILE"].value_counts().index)

sns.countplot(x = df["MOBILE"], ax = ax[0])
plt.pie(percentage,labels = labels, autopct= "%0.2f%%")  

plt.show()

# %% [markdown]
# ### all clients provided mobile phone number when applying for loan

# %%
info_of_cat('WORK_PHONE')
# Out:
# Unique values in WORK_PHONE are: [1 0]
# Mode of WORK_PHONE is 1
# Number of missing values in WORK_PHONE is 0

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
ax[0].set_title("WORK_PHONE")                  
percentage = df["WORK_PHONE"].value_counts()        
labels = list(df["WORK_PHONE"].value_counts().index)

sns.countplot(x = df["WORK_PHONE"], ax = ax[0])
plt.pie(percentage,labels = labels, autopct= "%0.2f%%")  

plt.show()

# %% [markdown]
# ### 17.87% clients did not provided work phone and 82.13 % client provided work phone

# %%
info_of_cat('HOME_PHONE')
# Out:
# Unique values in HOME_PHONE are: [0 1]
# Mode of HOME_PHONE is 0
# Number of missing values in HOME_PHONE is 0

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
ax[0].set_title("HOME_PHONE")                  
percentage = df["HOME_PHONE"].value_counts()        
labels = list(df["HOME_PHONE"].value_counts().index)

sns.countplot(x = df["HOME_PHONE"], ax = ax[0])
plt.pie(percentage,labels = labels, autopct= "%0.2f%%")  

plt.show()

# %% [markdown]
# ### only about 20% clients provided home phone number, and rest did not.3

# %%
info_of_cat('MOBILE_REACHABLE')
# Out:
# Unique values in MOBILE_REACHABLE are: [1 0]
# Mode of MOBILE_REACHABLE is 1
# Number of missing values in MOBILE_REACHABLE is 0

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
ax[0].set_title("MOBILE_REACHABLE")                  
percentage = df["MOBILE_REACHABLE"].value_counts()        
labels = list(df["MOBILE_REACHABLE"].value_counts().index)

sns.countplot(x = df["MOBILE_REACHABLE"], ax = ax[0])
plt.pie(percentage,labels = labels, autopct= "%0.2f%%")  

plt.show()

# %% [markdown]
# ### almost all clients mobile phone was reachable

# %%
info_of_cat('FLAG_EMAIL')
# Out:
# Unique values in FLAG_EMAIL are: [0 1]
# Mode of FLAG_EMAIL is 0
# Number of missing values in FLAG_EMAIL is 0

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
ax[0].set_title("FLAG_EMAIL")                  
percentage = df["FLAG_EMAIL"].value_counts()        
labels = list(df["FLAG_EMAIL"].value_counts().index)

sns.countplot(x = df["FLAG_EMAIL"], ax = ax[0])
plt.pie(percentage,labels = labels, autopct= "%0.2f%%")  

plt.show()

# %% [markdown]
# ### only 5.62% clients did not provided email address and rest all provided

# %%
info_of_cat('OCCUPATION_TYPE')
# Out:
# Unique values in OCCUPATION_TYPE are: ['Laborers' 'Core staff' 'Accountants' 'Managers' nan 'Drivers'
#  'Sales staff' 'Cleaning staff' 'Cooking staff' 'Private service staff'
#  'Medicine staff' 'Security staff' 'High skill tech staff'
#  'Waiters/barmen staff' 'Low-skill Laborers' 'Realty agents' 'Secretaries'
#  'IT staff' 'HR staff']
# Mode of OCCUPATION_TYPE is Laborers
# Number of missing values in OCCUPATION_TYPE is 31224

# %%
df['OCCUPATION_TYPE'].fillna('Unknown',inplace=True) #there were very large number of null column so its better to fill them with UNKNOWN keywork

# %%
fig, ax = plt.subplots(1, 2, figsize = (25, 7))
ax[0].set_title("OCCUPATION_TYPE")                  
percentage = df["OCCUPATION_TYPE"].value_counts()        
labels = list(df["OCCUPATION_TYPE"].value_counts().index)

sns.countplot(x = df["OCCUPATION_TYPE"], ax = ax[0])
plt.pie(percentage,labels = labels, autopct= "%0.2f%%")  

plt.show()

# %% [markdown]
# ### almost 31.22% occoupation is not known, and 18% were laborers and 10 % were from sales staff

# %%
info_of_cat('CNT_FAM_MEMBERS')
# Out:
# Unique values in CNT_FAM_MEMBERS are: [ 1.  2.  3.  4.  5.  6.  9.  7.  8. 10. 13. nan 14.]
# Mode of CNT_FAM_MEMBERS is 2.0
# Number of missing values in CNT_FAM_MEMBERS is 1

# %%
CNT_FAM_MEMBERS_mode=df.CNT_FAM_MEMBERS.mode()[0]
print(CNT_FAM_MEMBERS_mode)
df['CNT_FAM_MEMBERS'].fillna(CNT_FAM_MEMBERS_mode,inplace=True)
# Out:
# 2.0

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
ax[0].set_title("CNT_FAM_MEMBERS")                  
percentage = df["CNT_FAM_MEMBERS"].value_counts()        
labels = list(df["CNT_FAM_MEMBERS"].value_counts().index)

sns.countplot(x = df["CNT_FAM_MEMBERS"], ax = ax[0])
plt.pie(percentage,labels = labels, autopct= "%0.2f%%")  

plt.show()

# %% [markdown]
# ### majority of client(51.72%) have 2 family members and 21.81% have 1 family members and 17% have 3 family members

# %%
info_of_cat('APPLICATION_DAY')
# Out:
# Unique values in APPLICATION_DAY are: ['WEDNESDAY' 'MONDAY' 'THURSDAY' 'SUNDAY' 'SATURDAY' 'FRIDAY' 'TUESDAY']
# Mode of APPLICATION_DAY is TUESDAY
# Number of missing values in APPLICATION_DAY is 0

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
ax[0].set_title("APPLICATION_DAY")                  
percentage = df["APPLICATION_DAY"].value_counts()        
labels = list(df["APPLICATION_DAY"].value_counts().index)

sns.countplot(x = df["APPLICATION_DAY"], ax = ax[0])
plt.pie(percentage,labels = labels, autopct= "%0.2f%%")  

plt.show()

# %% [markdown]
# ### on sunday least application were recieved by bank for loan ie about 5% and on rest week days same almost portion of application is recieved by bank

# %%
info_of_cat('TOTAL_DOC_SUBMITTED')
# Out:
# Unique values in TOTAL_DOC_SUBMITTED are: [1 0 2 3 4]
# Mode of TOTAL_DOC_SUBMITTED is 1
# Number of missing values in TOTAL_DOC_SUBMITTED is 0

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
ax[0].set_title("TOTAL_DOC_SUBMITTED")                  
percentage = df["TOTAL_DOC_SUBMITTED"].value_counts()        
labels = list(df["TOTAL_DOC_SUBMITTED"].value_counts().index)

sns.countplot(x = df["TOTAL_DOC_SUBMITTED"], ax = ax[0])
plt.pie(percentage,labels = labels, autopct= "%0.2f%%")  

plt.show()

# %% [markdown]
# ### 87.86% client have submitted nly 1 document and 9.54% havent submitted a document at all

# %% [markdown]
# # Level 2 Analysis:

# %% [markdown]
# Relationshop between TARGET and NAME_CONTRACT_TYPE

# %%
fig, ax = plt.subplots(figsize = (10, 7))
sns.countplot(x = "House", hue = "TARGET", data = df)
plt.show()

# %% [markdown]
# ### Interpretation: clients who owns house are more in defaulter category as compared to who dont own

# %%
fig, ax = plt.subplots(figsize = (10, 7))
sns.countplot(x = "NAME_CONTRACT_TYPE", hue = "TARGET", data = df)
plt.show()

# %% [markdown]
# ### Interpretation: 90% of defaulter Clients are in Cash loans

# %%
fig, ax = plt.subplots(figsize = (10, 7))
sns.countplot(x = "GENDER", hue = "TARGET", data = df)
plt.show()

# %% [markdown]
# ### Interpretation: female clients are more in numbers in terms of defaulter as compared to male

# %%
fig, ax = plt.subplots(figsize = (10, 7))
sns.countplot(x = "Car", hue = "TARGET", data = df)
plt.show()

# %% [markdown]
# ### Interpretation: Clients who dont own a car are more defaulter as compared to who owns

# %%
fig, ax = plt.subplots(figsize = (12, 7))
sns.countplot(x = "NAME_EDUCATION_TYPE", hue = "TARGET", data = df)
plt.show()

# %% [markdown]
# ### Interpretation: Most of defaulter are have education type as secondary or higher education
#
# ### and Clients who have academic degree are not defaulters

# %%
fig, ax = plt.subplots(figsize = (12, 7))
sns.countplot(x = "NAME_FAMILY_STATUS", hue = "TARGET", data = df)
plt.show()

# %% [markdown]
# ### Interpretation: Most of defaulter are in Married Category
# ### and less defaulter clints are in widow and separated category.

# %%
fig, ax = plt.subplots(figsize = (12, 7))
sns.countplot(x = "TOTAL_DOC_SUBMITTED", hue = "TARGET", data = df)
plt.show()

# %% [markdown]
# ### Most of defaulter are from 1 document submitted category. and there are almost very less defaulter those who submitted 2,3,4 documents

# %%
fig, ax = plt.subplots(figsize = (25, 7))
sns.countplot(x = "OCCUPATION_TYPE", hue = "TARGET", data = df)
plt.show()

# %% [markdown]
# ### we can see almost all defaulters are from unknown or laborers and sales staff category

# %%
fig, ax = plt.subplots(figsize = (20, 7))
sns.countplot(x = "FLAG_EMAIL", hue = "TARGET", data = df)
plt.show()

# %% [markdown]
# ### ALMOST ALL DEFAULTERS ARE FROM CATEGORY WHO HAVE NOT PROVIDED EMAIL

# %%
df[(df['NAME_CONTRACT_TYPE']=='Cash loans')&(df['NAME_EDUCATION_TYPE']=='Secondary / secondary special')&(df['FLAG_EMAIL']==0)&((df['OCCUPATION_TYPE']=='Unknown')|(df['OCCUPATION_TYPE']=='Laborers'))&(df['TOTAL_DOC_SUBMITTED']==1)&(df['NAME_FAMILY_STATUS']=='Married')&(df['Car']=='N')]
# Out:
#        SK_ID_CURR  TARGET NAME_CONTRACT_TYPE GENDER Car House  CNT_CHILDREN  \
# 5          100008       0         Cash loans      M   N     Y             0
# 8          100011       0         Cash loans      F   N     Y             0
# 11         100015       0         Cash loans      F   N     Y             0
# 12         100016       0         Cash loans      F   N     Y             0
# 14         100018       0         Cash loans      F   N     Y             0
# ...           ...     ...                ...    ...  ..   ...           ...
# 99973      216063       0         Cash loans      F   N     N             0
# 99981      216072       0         Cash loans      F   N     Y             0
# 99982      216073       0         Cash loans      F   N     Y             0
# 99988      216079       0         Cash loans      M   N     Y             2
# 99989      216080       0         Cash loans      F   N     Y             0
#
# ...

# %% [markdown]
# ### These above customers have higher probability of becoming a defaulter.
# category for higher probability defaulter-
# 1-Cash Loans
# 2-Secondary / secondary special
# 3-Does not have email address
# 4-occupation-unknown and laborers
# 5-only 1 document submitted
# 6-married
# 7-does not own a car

# %% [markdown]
# ### based on above analysis Lower probability of becoming a defaulters are-
# 1-provided Email
# 2-occupation type - accounting, IT staff,HR staff, secretary, managers , security staff, cleaning staff
# 3-number of document submitted - 2,3,4
# 4-family status-single,widow,seperated,civil marrige
# 5-Those who have completed higher education,lower seconday,acedemic degree
# 6-gender- male
# 7- owns car
# 8-does not owns house
# 9-have revolving loans
